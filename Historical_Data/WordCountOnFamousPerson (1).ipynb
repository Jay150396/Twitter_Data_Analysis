# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-LAPUB8T:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Following Count:{ith_tweet[1]}")
    print(f"Follower Count:{ith_tweet[2]}")
    print(f"Total Tweets:{ith_tweet[3]}")
    print(f"Retweet Count:{ith_tweet[4]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username','following','followers', 'totaltweets', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,following,followers,totaltweets, retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'zsTrAIqVMAl6fMjd3aCnc243e'
consumer_secret = 'bezIY6xoFrQTVr0BYdinyyd8eVc60JNDaXMCWFXr3blfVZ9PV0'
access_key = '1059163618317606912-u4xy1i6vU5eptnQxnka9HXvz2eCNX6'
access_secret = 'YQFGmkCYKIyDLmMO4Nfw3iRjPAMY9E4MtfLacmgohOsSI'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "ELon Musk"
date_since = "2020-08-10"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:vincent13031925
# Following Count:248
# Follower Count:112610
# Total Tweets:44320
# Retweet Count:0
#
# Tweet 2:
# Username:Greggor22189796
# Following Count:422
# Follower Count:177
# Total Tweets:593
# Retweet Count:18
#
# Tweet 3:
# Username:tradingwithmose
# Following Count:351
# Follower Count:126
# Total Tweets:2404
# Retweet Count:147
#
# Tweet 4:
# Username:MarilinNarvaja
# Following Count:1044
# Follower Count:1066
# Total Tweets:24536
# Retweet Count:468
#
# Tweet 5:
# Username:Jeremia07960601
# Following Count:218
# Follower Count:301
# Total Tweets:10143
# Retweet Count:18
#
# Tweet 6:
# Username:hyhsyc
# Following Count:126
# Follower Count:13
# Total Tweets:1098
# Retweet Count:6
#
# Tweet 7:
# Username:bigdaddyiris
# Following Count:615
# Follower Count:7678
# Total Tweets:27441
# Retweet Count:0
#
# Tweet 8:
# Username:undrcvr_sprstar
# Following Count:309
# Follower Count:450
# Total Tweets:14315
# Retweet Count:0
#
# Tweet 9:
# Username:Kristennetten
# Following Count:4257
# Follower Count:43828
# Total Tweets:130472
# Retweet Count:18
#
# Tweet 10:
# Username:feministangel13
# Following Count:419
# Follower Count:155
# Total Tweets:9635
# Retweet Count:0
#
# Tweet 11:
# Username:LeroyMenez
# Following Count:56
# Follower Count:7
# Total Tweets:263
# Retweet Count:0
#
# Tweet 12:
# Username:tangojoshua
# Following Count:3525
# Follower Count:706
# Total Tweets:35966
# Retweet Count:147
#
# Tweet 13:
# Username:TheMissionman4
# Following Count:1093
# Follower Count:134
# Total Tweets:386
# Retweet Count:0
#
# Tweet 14:
# Username:DR0N3L0RD
# Following Count:235
# Follower Count:126
# Total Tweets:18618
# Retweet Count:0
#
# Tweet 15:
# Username:JayKilgore7
# Following Count:4596
# Follower Count:4566
# Total Tweets:55077
# Retweet Count:0
#
# Tweet 16:
# Username:EddyGarciaVega
# Following Count:863
# Follower Count:1430
# Total Tweets:116114
# Retweet Count:2
#
# Tweet 17:
# Username:USA_1st_2022
# Following Count:245
# Follower Count:156
# Total Tweets:27867
# Retweet Count:1
#
# Tweet 18:
# Username:InCLiNix1
# Following Count:52
# Follower Count:16
# Total Tweets:376
# Retweet Count:141
#
# Tweet 19:
# Username:AriStyle88
# Following Count:140
# Follower Count:107
# Total Tweets:989
# Retweet Count:0
#
# Tweet 20:
# Username:stromboliratio
# Following Count:186
# Follower Count:67
# Total Tweets:2545
# Retweet Count:147
#
# Tweet 21:
# Username:griffd
# Following Count:1156
# Follower Count:287
# Total Tweets:9607
# Retweet Count:18
#
# Tweet 22:
# Username:lilitharchives
# Following Count:164
# Follower Count:40
# Total Tweets:402
# Retweet Count:0
#
# Tweet 23:
# Username:BNelden
# Following Count:1796
# Follower Count:1009
# Total Tweets:11790
# Retweet Count:72
#
# Tweet 24:
# Username:ngrossman2000
# Following Count:433
# Follower Count:74
# Total Tweets:10290
# Retweet Count:2
#
# Tweet 25:
# Username:HMGoodenauthor
# Following Count:4411
# Follower Count:2926
# Total Tweets:4870
# Retweet Count:655
#
# Tweet 26:
# Username:JoeSmithSDK
# Following Count:389
# Follower Count:1347
# Total Tweets:89673
# Retweet Count:0
#
# Tweet 27:
# Username:MTrider16
# Following Count:821
# Follower Count:293
# Total Tweets:10871
# Retweet Count:0
#
# Tweet 28:
# Username:chilinhle3
# Following Count:22
# Follower Count:2
# Total Tweets:24
# Retweet Count:2507
#
# Tweet 29:
# Username:Elpanson123
# Following Count:156
# Follower Count:289
# Total Tweets:19775
# Retweet Count:147
#
# Tweet 30:
# Username:EugeneNg_VCap
# Following Count:838
# Follower Count:5762
# Total Tweets:5151
# Retweet Count:0
#
# Tweet 31:
# Username:goldtoochunky77
# Following Count:290
# Follower Count:143
# Total Tweets:29055
# Retweet Count:147
#
# Tweet 32:
# Username:EtherialBitch
# Following Count:1126
# Follower Count:128
# Total Tweets:33700
# Retweet Count:2
#
# Tweet 33:
# Username:AxelRanghar
# Following Count:161
# Follower Count:153
# Total Tweets:1370
# Retweet Count:139
#
# Tweet 34:
# Username:orieshafer
# Following Count:1353
# Follower Count:1298
# Total Tweets:3664
# Retweet Count:0
#
# Tweet 35:
# Username:fleursfaiches
# Following Count:740
# Follower Count:771
# Total Tweets:41740
# Retweet Count:468
#
# Tweet 36:
# Username:Miranda_Dragon
# Following Count:2197
# Follower Count:2464
# Total Tweets:18648
# Retweet Count:2
#
# Tweet 37:
# Username:channel_clear
# Following Count:832
# Follower Count:657
# Total Tweets:111290
# Retweet Count:0
#
# Tweet 38:
# Username:InvariantPersp1
# Following Count:5002
# Follower Count:3369
# Total Tweets:41877
# Retweet Count:2
#
# Tweet 39:
# Username:SabrinaZafar
# Following Count:398
# Follower Count:59
# Total Tweets:420
# Retweet Count:0
#
# Tweet 40:
# Username:W41k3r67342
# Following Count:997
# Follower Count:150
# Total Tweets:2221
# Retweet Count:90
#
# Tweet 41:
# Username:VegasCumQueen
# Following Count:973
# Follower Count:9024
# Total Tweets:2223
# Retweet Count:36
#
# Tweet 42:
# Username:arts_evi
# Following Count:168
# Follower Count:5800
# Total Tweets:1163
# Retweet Count:2
#
# Tweet 43:
# Username:Cranky_Cracknot
# Following Count:870
# Follower Count:147
# Total Tweets:38341
# Retweet Count:0
#
# Tweet 44:
# Username:ClubBayern
# Following Count:3293
# Follower Count:3816
# Total Tweets:109467
# Retweet Count:92
#
# Tweet 45:
# Username:pauljlaverty
# Following Count:2741
# Follower Count:2956
# Total Tweets:8864
# Retweet Count:0
#
# Tweet 46:
# Username:catchit16
# Following Count:3221
# Follower Count:750
# Total Tweets:69077
# Retweet Count:147
#
# Tweet 47:
# Username:Felix98069278
# Following Count:224
# Follower Count:265
# Total Tweets:26023
# Retweet Count:147
#
# Tweet 48:
# Username:WEBuffett1
# Following Count:75
# Follower Count:1474
# Total Tweets:11826
# Retweet Count:0
#
# Tweet 49:
# Username:Major_Kitty
# Following Count:658
# Follower Count:51
# Total Tweets:8203
# Retweet Count:0
#
# Tweet 50:
# Username:TESLA_is_FUTURE
# Following Count:172
# Follower Count:1231
# Total Tweets:4164
# Retweet Count:147
#
# Tweet 51:
# Username:kyeexx_
# Following Count:573
# Follower Count:30
# Total Tweets:3121
# Retweet Count:564
#
# Tweet 52:
# Username:BRSN777
# Following Count:195
# Follower Count:3100
# Total Tweets:2303
# Retweet Count:147
#
# Tweet 53:
# Username:GarrettCGleaton
# Following Count:752
# Follower Count:74
# Total Tweets:1608
# Retweet Count:147
#
# Tweet 54:
# Username:ShepTheMusicalG
# Following Count:1997
# Follower Count:2084
# Total Tweets:13173
# Retweet Count:267
#
# Tweet 55:
# Username:cg3designs
# Following Count:61
# Follower Count:24
# Total Tweets:1651
# Retweet Count:0
#
# Tweet 56:
# Username:LesliePicker
# Following Count:2040
# Follower Count:27434
# Total Tweets:8044
# Retweet Count:147
#
# Tweet 57:
# Username:USTesla
# Following Count:261
# Follower Count:54
# Total Tweets:2775
# Retweet Count:1
#
# Tweet 58:
# Username:kbrig33
# Following Count:217
# Follower Count:125
# Total Tweets:438
# Retweet Count:14
#
# Tweet 59:
# Username:pittajetty24
# Following Count:809
# Follower Count:288
# Total Tweets:18715
# Retweet Count:147
#
# Tweet 60:
# Username:AstroPotamus
# Following Count:2
# Follower Count:719
# Total Tweets:51531
# Retweet Count:1
#
# Tweet 61:
# Username:lydiacostume
# Following Count:996
# Follower Count:169
# Total Tweets:15302
# Retweet Count:7
#
# Tweet 62:
# Username:Luarien
# Following Count:846
# Follower Count:715
# Total Tweets:166997
# Retweet Count:3
#
# Tweet 63:
# Username:channel_clear
# Following Count:832
# Follower Count:657
# Total Tweets:111290
# Retweet Count:5
#
# Tweet 64:
# Username:LlcGilmore
# Following Count:1592
# Follower Count:69
# Total Tweets:1951
# Retweet Count:102
#
# Tweet 65:
# Username:LlcGilmore
# Following Count:1592
# Follower Count:69
# Total Tweets:1951
# Retweet Count:74
#
# Tweet 66:
# Username:LlcGilmore
# Following Count:1592
# Follower Count:69
# Total Tweets:1951
# Retweet Count:179
#
# Tweet 67:
# Username:LaxmanS27729423
# Following Count:29
# Follower Count:1
# Total Tweets:18
# Retweet Count:0
#
# Tweet 68:
# Username:Verlante
# Following Count:83
# Follower Count:18
# Total Tweets:1060
# Retweet Count:0
#
# Tweet 69:
# Username:LlcGilmore
# Following Count:1592
# Follower Count:69
# Total Tweets:1951
# Retweet Count:129
#
# Tweet 70:
# Username:Goony_AU
# Following Count:1410
# Follower Count:2670
# Total Tweets:7082
# Retweet Count:0
#
# Tweet 71:
# Username:CarConcerns
# Following Count:9835
# Follower Count:15847
# Total Tweets:90586
# Retweet Count:0
#
# Tweet 72:
# Username:ment2ride
# Following Count:315
# Follower Count:9
# Total Tweets:418
# Retweet Count:90
#
# Tweet 73:
# Username:TheDogeSon1
# Following Count:1703
# Follower Count:1212
# Total Tweets:1644
# Retweet Count:0
#
# Tweet 74:
# Username:puppypuppi
# Following Count:868
# Follower Count:2500
# Total Tweets:86035
# Retweet Count:0
#
# Tweet 75:
# Username:yyyyy_johhny
# Following Count:331
# Follower Count:117
# Total Tweets:1000
# Retweet Count:90
#
# Tweet 76:
# Username:TukDhakal
# Following Count:380
# Follower Count:76
# Total Tweets:2439
# Retweet Count:0
#
# Tweet 77:
# Username:Canyonaro
# Following Count:200
# Follower Count:703
# Total Tweets:4586
# Retweet Count:2
#
# Tweet 78:
# Username:NaturalParadigm
# Following Count:2970
# Follower Count:2543
# Total Tweets:23850
# Retweet Count:0
#
# Tweet 79:
# Username:Jeffreylestes
# Following Count:339
# Follower Count:60
# Total Tweets:2199
# Retweet Count:0
#
# Tweet 80:
# Username:HealhGlyn
# Following Count:161
# Follower Count:855
# Total Tweets:244552
# Retweet Count:9
#
# Tweet 81:
# Username:AlexDaUkrainian
# Following Count:626
# Follower Count:1270
# Total Tweets:17108
# Retweet Count:0
#
# Tweet 82:
# Username:jadeisexhausted
# Following Count:167
# Follower Count:62
# Total Tweets:7021
# Retweet Count:468
#
# Tweet 83:
# Username:GhostRhyder_
# Following Count:130
# Follower Count:35
# Total Tweets:3395
# Retweet Count:139
#
# Tweet 84:
# Username:jcperez7568
# Following Count:97
# Follower Count:53
# Total Tweets:3601
# Retweet Count:90
#
# Tweet 85:
# Username:Peter_Atwater
# Following Count:1105
# Follower Count:23990
# Total Tweets:27111
# Retweet Count:2
#
# Tweet 86:
# Username:py9fmUwezkacRQ9
# Following Count:11
# Follower Count:1
# Total Tweets:6
# Retweet Count:0
#
# Tweet 87:
# Username:kannajaeymoney
# Following Count:5
# Follower Count:0
# Total Tweets:4
# Retweet Count:0
#
# Tweet 88:
# Username:agnxw
# Following Count:38
# Follower Count:13
# Total Tweets:169
# Retweet Count:0
#
# Tweet 89:
# Username:janel_bonnie
# Following Count:2966
# Follower Count:822
# Total Tweets:45038
# Retweet Count:2
#
# Tweet 90:
# Username:s_dacal
# Following Count:232
# Follower Count:51
# Total Tweets:15414
# Retweet Count:71
#
# Tweet 91:
# Username:The220Podcast
# Following Count:4905
# Follower Count:4010
# Total Tweets:9772
# Retweet Count:0
#
# Tweet 92:
# Username:leonard_per
# Following Count:156
# Follower Count:264
# Total Tweets:17117
# Retweet Count:71
#
# Tweet 93:
# Username:Inc
# Following Count:1695
# Follower Count:2777448
# Total Tweets:316600
# Retweet Count:2
#
# Tweet 94:
# Username:DavidRSimpkins2
# Following Count:103
# Follower Count:43
# Total Tweets:7047
# Retweet Count:6
#
# Tweet 95:
# Username:FightClubTesla
# Following Count:385
# Follower Count:119
# Total Tweets:13599
# Retweet Count:90
#
# Tweet 96:
# Username:Quixotic3lixer
# Following Count:507
# Follower Count:108
# Total Tweets:2708
# Retweet Count:0
#
# Tweet 97:
# Username:Dilophosaur13
# Following Count:3383
# Follower Count:1039
# Total Tweets:89350
# Retweet Count:0
#
# Tweet 98:
# Username:mahsih7
# Following Count:286
# Follower Count:155
# Total Tweets:1260
# Retweet Count:1093
#
# Tweet 99:
# Username:Pauldanne1
# Following Count:185
# Follower Count:68
# Total Tweets:12040
# Retweet Count:47
#
# Tweet 100:
# Username:MuskNL
# Following Count:0
# Follower Count:685
# Total Tweets:5103
# Retweet Count:1
