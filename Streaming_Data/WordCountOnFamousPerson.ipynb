# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-LAPUB8T:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc.stop()

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Following Count:{ith_tweet[0]}")
    print(f"Follower Count:{ith_tweet[1]}")
    print(f"Total Tweets:{ith_tweet[2]}")
    print(f"Retweet Count:{ith_tweet[3]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['following','followers', 'totaltweets', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [following,followers,totaltweets, retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'zsTrAIqVMAl6fMjd3aCnc243e'
consumer_secret = 'bezIY6xoFrQTVr0BYdinyyd8eVc60JNDaXMCWFXr3blfVZ9PV0'
access_key = '1059163618317606912-u4xy1i6vU5eptnQxnka9HXvz2eCNX6'
access_secret = 'YQFGmkCYKIyDLmMO4Nfw3iRjPAMY9E4MtfLacmgohOsSI'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "ELon Musk"
date_since = "2020-08-10"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Following Count:4776
# Follower Count:4357
# Total Tweets:30248
# Retweet Count:0
#
# Following Count:17
# Follower Count:230
# Total Tweets:486
# Retweet Count:53
#
# Following Count:36
# Follower Count:38
# Total Tweets:1333
# Retweet Count:0
#
# Following Count:2895
# Follower Count:1875
# Total Tweets:8350
# Retweet Count:23
#
# Following Count:363
# Follower Count:406
# Total Tweets:3505
# Retweet Count:23
#
# Following Count:2436
# Follower Count:1460
# Total Tweets:10526
# Retweet Count:0
#
# Following Count:978
# Follower Count:786
# Total Tweets:27678
# Retweet Count:23
#
# Following Count:67
# Follower Count:23
# Total Tweets:110
# Retweet Count:0
#
# Following Count:12943
# Follower Count:12008
# Total Tweets:67635
# Retweet Count:0
#
# Following Count:10
# Follower Count:0
# Total Tweets:984
# Retweet Count:0
#
# Following Count:58
# Follower Count:110
# Total Tweets:2836
# Retweet Count:23
#
# Following Count:268
# Follower Count:204
# Total Tweets:371
# Retweet Count:23
#
# Following Count:1400
# Follower Count:1194
# Total Tweets:9709
# Retweet Count:23
#
# Following Count:1812
# Follower Count:2797
# Total Tweets:14892
# Retweet Count:23
#
# Following Count:915
# Follower Count:489
# Total Tweets:4885
# Retweet Count:23
#
# Following Count:237
# Follower Count:1001
# Total Tweets:1183
# Retweet Count:23
#
# Following Count:0
# Follower Count:2
# Total Tweets:11
# Retweet Count:0
#
# Following Count:984
# Follower Count:848
# Total Tweets:43787
# Retweet Count:808
#
# Following Count:2
# Follower Count:701
# Total Tweets:50176
# Retweet Count:2
#
# Following Count:152
# Follower Count:114
# Total Tweets:5633
# Retweet Count:23
#
# Following Count:388
# Follower Count:87
# Total Tweets:908
# Retweet Count:370
#
# Following Count:3599
# Follower Count:1896
# Total Tweets:15895
# Retweet Count:23
#
# Following Count:3533
# Follower Count:2227
# Total Tweets:11804
# Retweet Count:552
#
# Following Count:372
# Follower Count:226
# Total Tweets:763
# Retweet Count:509
#
# Following Count:2796
# Follower Count:296
# Total Tweets:13398
# Retweet Count:23
#
# Following Count:243
# Follower Count:232
# Total Tweets:9499
# Retweet Count:657
#
# Following Count:141281
# Follower Count:179134
# Total Tweets:9555
# Retweet Count:30
#
# Following Count:366
# Follower Count:280
# Total Tweets:1858
# Retweet Count:23
#
# Following Count:4446
# Follower Count:109
# Total Tweets:27321
# Retweet Count:564
#
# Following Count:850
# Follower Count:442
# Total Tweets:5056
# Retweet Count:552
#
# Following Count:44
# Follower Count:130
# Total Tweets:993
# Retweet Count:23
#
# Following Count:1861
# Follower Count:2224
# Total Tweets:6798
# Retweet Count:23
#
# Following Count:55
# Follower Count:22
# Total Tweets:79
# Retweet Count:47
#
# Following Count:65
# Follower Count:44
# Total Tweets:47
# Retweet Count:0
#
# Following Count:4526
# Follower Count:6215
# Total Tweets:3440
# Retweet Count:0
#
# Following Count:48
# Follower Count:5
# Total Tweets:76
# Retweet Count:509
#
# Following Count:1111
# Follower Count:1064
# Total Tweets:5880
# Retweet Count:23
#
# Following Count:210
# Follower Count:108
# Total Tweets:6275
# Retweet Count:552
#
# Following Count:540
# Follower Count:156
# Total Tweets:3088
# Retweet Count:0
#
# Following Count:723
# Follower Count:1089
# Total Tweets:97601
# Retweet Count:509
#
# Following Count:4987
# Follower Count:3768
# Total Tweets:62068
# Retweet Count:0
#
# Following Count:4988
# Follower Count:2727
# Total Tweets:818667
# Retweet Count:16
#
# Following Count:1777
# Follower Count:2222
# Total Tweets:60672
# Retweet Count:47
#
# Following Count:875
# Follower Count:574
# Total Tweets:6943
# Retweet Count:808
#
# Following Count:4441
# Follower Count:1895
# Total Tweets:32795
# Retweet Count:552
#
# Following Count:733
# Follower Count:676
# Total Tweets:176287
# Retweet Count:29
#
# Following Count:3584
# Follower Count:3625
# Total Tweets:5889
# Retweet Count:23
#
# Following Count:13328
# Follower Count:13577
# Total Tweets:45726
# Retweet Count:23
#
# Following Count:2786
# Follower Count:3013
# Total Tweets:37982
# Retweet Count:23
#
# Following Count:601
# Follower Count:155
# Total Tweets:30509
# Retweet Count:8
#
# Following Count:28
# Follower Count:190
# Total Tweets:118091
# Retweet Count:1
#
# Following Count:379
# Follower Count:215
# Total Tweets:3574
# Retweet Count:23
#
# Following Count:1075
# Follower Count:59
# Total Tweets:16335
# Retweet Count:23
#
# Following Count:89
# Follower Count:116228
# Total Tweets:1335
# Retweet Count:23
#
# Following Count:1778
# Follower Count:3490
# Total Tweets:62881
# Retweet Count:1
#
# Following Count:345
# Follower Count:291
# Total Tweets:2425
# Retweet Count:552
#
# Following Count:2
# Follower Count:701
# Total Tweets:50177
# Retweet Count:1
#
# Following Count:36
# Follower Count:38
# Total Tweets:1333
# Retweet Count:0
#
# Following Count:4994
# Follower Count:959
# Total Tweets:41724
# Retweet Count:143
#
# Following Count:1015
# Follower Count:839
# Total Tweets:6571
# Retweet Count:808
#
# Following Count:4994
# Follower Count:959
# Total Tweets:41724
# Retweet Count:95
#
# Following Count:5001
# Follower Count:2581
# Total Tweets:25874
# Retweet Count:0
#
# Following Count:4994
# Follower Count:959
# Total Tweets:41724
# Retweet Count:509
#
# Following Count:236
# Follower Count:19
# Total Tweets:261
# Retweet Count:0
#
# Following Count:258
# Follower Count:162
# Total Tweets:12544
# Retweet Count:509
#
# Following Count:79
# Follower Count:358
# Total Tweets:36829
# Retweet Count:0
#
# Following Count:548
# Follower Count:137
# Total Tweets:68198
# Retweet Count:0
#
# Following Count:2646
# Follower Count:1188
# Total Tweets:15556
# Retweet Count:552
#
# Following Count:1149
# Follower Count:727
# Total Tweets:34333
# Retweet Count:0
#
# Following Count:53
# Follower Count:247
# Total Tweets:684
# Retweet Count:0
#
# Following Count:28
# Follower Count:424038
# Total Tweets:165779
# Retweet Count:1
#
# Following Count:283
# Follower Count:134
# Total Tweets:993
# Retweet Count:0
#
# Following Count:426
# Follower Count:671
# Total Tweets:20321
# Retweet Count:216
#
# Following Count:140
# Follower Count:50
# Total Tweets:382
# Retweet Count:0
#
# Following Count:1676
# Follower Count:331
# Total Tweets:2271
# Retweet Count:0
#
# Following Count:2545
# Follower Count:2869
# Total Tweets:48456
# Retweet Count:808
#
# Following Count:99
# Follower Count:14
# Total Tweets:237
# Retweet Count:370
#
# Following Count:15
# Follower Count:0
# Total Tweets:14
# Retweet Count:0
#
# Following Count:885
# Follower Count:784
# Total Tweets:86514
# Retweet Count:808
#
# Following Count:0
# Follower Count:1501
# Total Tweets:12749
# Retweet Count:0
#
# Following Count:687
# Follower Count:2254
# Total Tweets:860
# Retweet Count:0
#
# Following Count:995
# Follower Count:7351
# Total Tweets:31316
# Retweet Count:0
#
# Following Count:1252
# Follower Count:342
# Total Tweets:756
# Retweet Count:0
#
# Following Count:197
# Follower Count:421
# Total Tweets:125140
# Retweet Count:0
#
# Following Count:1382
# Follower Count:415
# Total Tweets:27308
# Retweet Count:808
#
# Following Count:96
# Follower Count:41
# Total Tweets:281
# Retweet Count:0
#
# Following Count:197
# Follower Count:421
# Total Tweets:125140
# Retweet Count:0
#
# Following Count:401
# Follower Count:37
# Total Tweets:12494
# Retweet Count:370
#
# Following Count:371
# Follower Count:288
# Total Tweets:4703
# Retweet Count:12
#
# Following Count:99
# Follower Count:232
# Total Tweets:69068
# Retweet Count:8
#
# Following Count:354
# Follower Count:986
# Total Tweets:9319
# Retweet Count:0
#
# Following Count:12
# Follower Count:1
# Total Tweets:8
# Retweet Count:0
#
# Following Count:175
# Follower Count:60
# Total Tweets:406
# Retweet Count:0
#
# Following Count:596
# Follower Count:482
# Total Tweets:5459
# Retweet Count:0
#
# Following Count:4329
# Follower Count:5368
# Total Tweets:63578
# Retweet Count:370
#
# Following Count:900
# Follower Count:1362
# Total Tweets:73590
# Retweet Count:0
#
# Following Count:9
# Follower Count:8
# Total Tweets:83
# Retweet Count:0
#
# Following Count:32
# Follower Count:3
# Total Tweets:81
# Retweet Count:0
#
# Following Count:0
# Follower Count:431
# Total Tweets:7167
# Retweet Count:808
#
# Following Count:130
# Follower Count:5
# Total Tweets:279
# Retweet Count:0
