# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-LAPUB8T:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Following Count:{ith_tweet[1]}")
    print(f"Follower Count:{ith_tweet[2]}")
    print(f"Total Tweets:{ith_tweet[3]}")
    print(f"Retweet Count:{ith_tweet[4]}")

# %%
def scrape(words, date_since, numtweet):
    df_pd = pd.DataFrame({'username':['foo'],'following':[1],'followers':[1], 'totaltweets':[1], 'retweetcount':[1]})
    db = spark.createDataFrame(df_pd)
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,following,followers,totaltweets, retweetcount]
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'zsTrAIqVMAl6fMjd3aCnc243e'
consumer_secret = 'bezIY6xoFrQTVr0BYdinyyd8eVc60JNDaXMCWFXr3blfVZ9PV0'
access_key = '1059163618317606912-u4xy1i6vU5eptnQxnka9HXvz2eCNX6'
access_secret = 'YQFGmkCYKIyDLmMO4Nfw3iRjPAMY9E4MtfLacmgohOsSI'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "ELon Musk"
date_since = "2020-08-10"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:Ciboyz3
# Following Count:593
# Follower Count:20
# Total Tweets:180
# Retweet Count:9496
#
# Tweet 2:
# Username:BannaOfficial10
# Following Count:120
# Follower Count:0
# Total Tweets:200
# Retweet Count:9496
#
# Tweet 3:
# Username:NagyVasile2
# Following Count:104
# Follower Count:15
# Total Tweets:162
# Retweet Count:207
#
# Tweet 4:
# Username:rathium
# Following Count:1456
# Follower Count:377
# Total Tweets:19183
# Retweet Count:48
#
# Tweet 5:
# Username:cueto_melvin
# Following Count:247
# Follower Count:76
# Total Tweets:3082
# Retweet Count:178
#
# Tweet 6:
# Username:Jobbar28948592
# Following Count:621
# Follower Count:9
# Total Tweets:1097
# Retweet Count:9496
#
# Tweet 7:
# Username:jubaer6969
# Following Count:183
# Follower Count:12
# Total Tweets:555
# Retweet Count:9493
#
# Tweet 8:
# Username:MdShaki4321
# Following Count:953
# Follower Count:44
# Total Tweets:2186
# Retweet Count:9496
#
# Tweet 9:
# Username:jeffrey22100513
# Following Count:25
# Follower Count:14
# Total Tweets:425
# Retweet Count:9
#
# Tweet 10:
# Username:goverment_is
# Following Count:2752
# Follower Count:1285
# Total Tweets:38664
# Retweet Count:5
#
# Tweet 11:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1430
# Retweet Count:1
#
# Tweet 12:
# Username:arisprihantoro7
# Following Count:75
# Follower Count:10
# Total Tweets:108
# Retweet Count:9496
#
# Tweet 13:
# Username:CryptoBarberBH
# Following Count:66
# Follower Count:69
# Total Tweets:1633
# Retweet Count:178
#
# Tweet 14:
# Username:eyasinbd010
# Following Count:177
# Follower Count:2
# Total Tweets:234
# Retweet Count:9496
#
# Tweet 15:
# Username:amoore6489
# Following Count:556
# Follower Count:146
# Total Tweets:18447
# Retweet Count:0
#
# Tweet 16:
# Username:KhandakarIkram
# Following Count:361
# Follower Count:52
# Total Tweets:771
# Retweet Count:9497
#
# Tweet 17:
# Username:kaysarahmed123
# Following Count:403
# Follower Count:14
# Total Tweets:924
# Retweet Count:207
#
# Tweet 18:
# Username:JibonAh41091748
# Following Count:464
# Follower Count:6
# Total Tweets:897
# Retweet Count:9497
#
# Tweet 19:
# Username:Reenath
# Following Count:156
# Follower Count:294
# Total Tweets:91070
# Retweet Count:9
#
# Tweet 20:
# Username:Alvarendra19
# Following Count:2982
# Follower Count:486
# Total Tweets:5769
# Retweet Count:9497
#
# Tweet 21:
# Username:srfsnt
# Following Count:485
# Follower Count:19
# Total Tweets:878
# Retweet Count:9497
#
# Tweet 22:
# Username:Shafiqul2003
# Following Count:39
# Follower Count:0
# Total Tweets:68
# Retweet Count:9497
#
# Tweet 23:
# Username:survive176
# Following Count:614
# Follower Count:133
# Total Tweets:770
# Retweet Count:9497
#
# Tweet 24:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1430
# Retweet Count:29
#
# Tweet 25:
# Username:ShahAmranBhuiy1
# Following Count:1229
# Follower Count:19
# Total Tweets:2241
# Retweet Count:9497
#
# Tweet 26:
# Username:SussTuthi
# Following Count:83
# Follower Count:0
# Total Tweets:46
# Retweet Count:9497
#
# Tweet 27:
# Username:TeslaForThe_Win
# Following Count:4999
# Follower Count:3180
# Total Tweets:40434
# Retweet Count:0
#
# Tweet 28:
# Username:vijayhiren
# Following Count:111
# Follower Count:29
# Total Tweets:65
# Retweet Count:9497
#
# Tweet 29:
# Username:NasrullohNova
# Following Count:637
# Follower Count:39
# Total Tweets:996
# Retweet Count:9497
#
# Tweet 30:
# Username:susuultra512
# Following Count:52
# Follower Count:2
# Total Tweets:42
# Retweet Count:9497
#
# Tweet 31:
# Username:KmSami11
# Following Count:71
# Follower Count:0
# Total Tweets:51
# Retweet Count:9497
#
# Tweet 32:
# Username:MQalichi
# Following Count:96
# Follower Count:1
# Total Tweets:112
# Retweet Count:9497
#
# Tweet 33:
# Username:DR0N3L0RD
# Following Count:235
# Follower Count:135
# Total Tweets:19288
# Retweet Count:0
#
# Tweet 34:
# Username:Naishad18084889
# Following Count:690
# Follower Count:32
# Total Tweets:1606
# Retweet Count:9497
#
# Tweet 35:
# Username:Sovit1234
# Following Count:112
# Follower Count:0
# Total Tweets:201
# Retweet Count:9497
#
# Tweet 36:
# Username:mohdharoon1217
# Following Count:50
# Follower Count:5
# Total Tweets:65
# Retweet Count:9497
#
# Tweet 37:
# Username:kaloky050
# Following Count:822
# Follower Count:146
# Total Tweets:3340
# Retweet Count:9497
#
# Tweet 38:
# Username:BLInjuryLaw
# Following Count:133
# Follower Count:11
# Total Tweets:36
# Retweet Count:18
#
# Tweet 39:
# Username:tithamore1
# Following Count:17
# Follower Count:0
# Total Tweets:30
# Retweet Count:9497
#
# Tweet 40:
# Username:Daironmonk1
# Following Count:144
# Follower Count:14
# Total Tweets:54
# Retweet Count:289
#
# Tweet 41:
# Username:Ankit92427997
# Following Count:1075
# Follower Count:11
# Total Tweets:51
# Retweet Count:48
#
# Tweet 42:
# Username:Rajibul34397555
# Following Count:188
# Follower Count:4
# Total Tweets:232
# Retweet Count:9497
#
# Tweet 43:
# Username:DerekMiller36
# Following Count:36138
# Follower Count:54280
# Total Tweets:96192
# Retweet Count:7
#
# Tweet 44:
# Username:RajanGunal
# Following Count:95
# Follower Count:0
# Total Tweets:98
# Retweet Count:9497
#
# Tweet 45:
# Username:indodropers
# Following Count:1208
# Follower Count:71
# Total Tweets:2406
# Retweet Count:9497
#
# Tweet 46:
# Username:Ricnotell
# Following Count:72
# Follower Count:183
# Total Tweets:13896
# Retweet Count:178
#
# Tweet 47:
# Username:Rujelk4Sab
# Following Count:402
# Follower Count:11
# Total Tweets:917
# Retweet Count:9498
#
# Tweet 48:
# Username:warren_tt
# Following Count:300
# Follower Count:1201
# Total Tweets:38746
# Retweet Count:0
#
# Tweet 49:
# Username:7t3yJqgAkWwM1KT
# Following Count:200
# Follower Count:42
# Total Tweets:953
# Retweet Count:7
#
# Tweet 50:
# Username:SopianH01882734
# Following Count:25
# Follower Count:19
# Total Tweets:16
# Retweet Count:9498
#
# Tweet 51:
# Username:TomasFrancis11
# Following Count:301
# Follower Count:107
# Total Tweets:2013
# Retweet Count:208
#
# Tweet 52:
# Username:zone8Heather
# Following Count:232
# Follower Count:181
# Total Tweets:2264
# Retweet Count:1130
#
# Tweet 53:
# Username:kalaippy
# Following Count:170
# Follower Count:62
# Total Tweets:648
# Retweet Count:48
#
# Tweet 54:
# Username:shesathriram198
# Following Count:560
# Follower Count:570
# Total Tweets:17098
# Retweet Count:4
#
# Tweet 55:
# Username:riotbrrri
# Following Count:201
# Follower Count:13
# Total Tweets:463
# Retweet Count:5
#
# Tweet 56:
# Username:NQamouta
# Following Count:131
# Follower Count:6
# Total Tweets:143
# Retweet Count:7
#
# Tweet 57:
# Username:SMPrinc01840330
# Following Count:399
# Follower Count:3
# Total Tweets:719
# Retweet Count:9498
#
# Tweet 58:
# Username:set_wint
# Following Count:489
# Follower Count:64
# Total Tweets:723
# Retweet Count:9498
#
# Tweet 59:
# Username:MJafryan
# Following Count:441
# Follower Count:0
# Total Tweets:1045
# Retweet Count:9498
#
# Tweet 60:
# Username:TanvirH36053645
# Following Count:284
# Follower Count:3
# Total Tweets:319
# Retweet Count:9498
#
# Tweet 61:
# Username:kdisla
# Following Count:791
# Follower Count:6910
# Total Tweets:5325
# Retweet Count:7
#
# Tweet 62:
# Username:abr36030225
# Following Count:3
# Follower Count:0
# Total Tweets:2
# Retweet Count:9498
#
# Tweet 63:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1430
# Retweet Count:3
#
# Tweet 64:
# Username:justatester13
# Following Count:31
# Follower Count:15
# Total Tweets:486
# Retweet Count:7
#
# Tweet 65:
# Username:ForbesCrypto
# Following Count:356
# Follower Count:334989
# Total Tweets:11130
# Retweet Count:7
#
# Tweet 66:
# Username:conorsmith
# Following Count:487
# Follower Count:1804
# Total Tweets:55066
# Retweet Count:0
#
# Tweet 67:
# Username:Arthur_Tkachuk
# Following Count:221
# Follower Count:549
# Total Tweets:22521
# Retweet Count:1
#
# Tweet 68:
# Username:crypto_recceh
# Following Count:280
# Follower Count:151
# Total Tweets:1836
# Retweet Count:9498
#
# Tweet 69:
# Username:EverythingSpce
# Following Count:323
# Follower Count:44
# Total Tweets:1101
# Retweet Count:48
#
# Tweet 70:
# Username:DMoficial11
# Following Count:9
# Follower Count:0
# Total Tweets:10
# Retweet Count:101
#
# Tweet 71:
# Username:recentlyRekt
# Following Count:1678
# Follower Count:179
# Total Tweets:2973
# Retweet Count:1
#
# Tweet 72:
# Username:joelson_dev
# Following Count:261
# Follower Count:60
# Total Tweets:1310
# Retweet Count:48
#
# Tweet 73:
# Username:AbDuLKa49887061
# Following Count:78
# Follower Count:5
# Total Tweets:117
# Retweet Count:9498
#
# Tweet 74:
# Username:Bithi13598396
# Following Count:722
# Follower Count:7
# Total Tweets:1562
# Retweet Count:9498
#
# Tweet 75:
# Username:r9r85Wm6KCceENj
# Following Count:56
# Follower Count:2
# Total Tweets:60
# Retweet Count:207
#
# Tweet 76:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1430
# Retweet Count:368
#
# Tweet 77:
# Username:weslopes
# Following Count:3233
# Follower Count:982
# Total Tweets:116595
# Retweet Count:48
#
# Tweet 78:
# Username:1969kervin
# Following Count:441
# Follower Count:150
# Total Tweets:2296
# Retweet Count:0
#
# Tweet 79:
# Username:Jirajones
# Following Count:1148
# Follower Count:6105
# Total Tweets:56453
# Retweet Count:0
#
# Tweet 80:
# Username:MdImran420181
# Following Count:17
# Follower Count:1
# Total Tweets:37
# Retweet Count:9498
#
# Tweet 81:
# Username:helloguys017
# Following Count:388
# Follower Count:36
# Total Tweets:342
# Retweet Count:9498
#
# Tweet 82:
# Username:KomengHelmi
# Following Count:41
# Follower Count:3
# Total Tweets:59
# Retweet Count:9498
#
# Tweet 83:
# Username:AnhThuy476
# Following Count:1
# Follower Count:0
# Total Tweets:7
# Retweet Count:101
#
# Tweet 84:
# Username:Crypto_Karthick
# Following Count:282
# Follower Count:11
# Total Tweets:1272
# Retweet Count:207
#
# Tweet 85:
# Username:stephfinebot
# Following Count:0
# Follower Count:9
# Total Tweets:87957
# Retweet Count:0
#
# Tweet 86:
# Username:AjiPras37773598
# Following Count:171
# Follower Count:7
# Total Tweets:380
# Retweet Count:9498
#
# Tweet 87:
# Username:MDHRIDOYSARKAR7
# Following Count:255
# Follower Count:3
# Total Tweets:691
# Retweet Count:9498
#
# Tweet 88:
# Username:Hasan56757626
# Following Count:736
# Follower Count:13
# Total Tweets:1298
# Retweet Count:9498
#
# Tweet 89:
# Username:Sourob04644344
# Following Count:424
# Follower Count:13
# Total Tweets:744
# Retweet Count:9498
#
# Tweet 90:
# Username:Anik77777
# Following Count:307
# Follower Count:16
# Total Tweets:876
# Retweet Count:9498
#
# Tweet 91:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1429
# Retweet Count:7
#
# Tweet 92:
# Username:Akmaltarue1
# Following Count:25
# Follower Count:19
# Total Tweets:14
# Retweet Count:9499
#
# Tweet 93:
# Username:Technicalsarfa1
# Following Count:498
# Follower Count:15
# Total Tweets:1128
# Retweet Count:9499
#
# Tweet 94:
# Username:onlineincome121
# Following Count:1056
# Follower Count:116
# Total Tweets:1100
# Retweet Count:9499
#
# Tweet 95:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1429
# Retweet Count:10448
#
# Tweet 96:
# Username:sisilyapratiwi
# Following Count:365
# Follower Count:22
# Total Tweets:1495
# Retweet Count:9499
#
# Tweet 97:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1429
# Retweet Count:14
#
# Tweet 98:
# Username:Riad36649321
# Following Count:31
# Follower Count:0
# Total Tweets:48
# Retweet Count:9499
#
# Tweet 99:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1429
# Retweet Count:6
#
# Tweet 100:
# Username:AlomAmit
# Following Count:1
# Follower Count:0
# Total Tweets:3
# Retweet Count:9499
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-06851eadd213> in <module>
# ----> 1 scrape(words, date_since, numtweet)
#
# <ipython-input-21-c602b44565cc> in scrape(words, date_since, numtweet)
#      21         i = i+1
#      22     filename = 'ScrapedTweets.csv'
# ---> 23     db.to_csv(filename)
#
# C:\opt\spark\spark-3.1.2-bin-hadoop3.2\python\pyspark\sql\dataframe.py in __getattr__(self, name)
#    1641         """
#    1642         if name not in self.columns:
# -> 1643             raise AttributeError(
#    1644                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1645         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_csv'

# %%
csv = spark.read.csv('ScrapedTweets.csv', inferSchema=True, header=True)
csv.show(10)
# Out:
# +---+--------------+---------+---------+-----------+------------+
# |_c0|      username|following|followers|totaltweets|retweetcount|
# +---+--------------+---------+---------+-----------+------------+
# |  0|   Smack_Check|      891|      848|      14532|           0|
# |  1|     karl_popp|      952|     1838|     196446|           0|
# |  2|     mr_awotwe|      179|      119|       1026|        1449|
# |  3|       C_Gritz|      752|     3689|      33423|           0|
# |  4| andredarmanin|     1153|     2304|      84327|           0|
# |  5|Wordsnflowers1|      769|      542|      92182|          21|
# |  6|     RicoBro31|       46|        6|          9|        2774|
# |  7| iamsameer1009|      193|      202|      28569|        1449|
# |  8|  freedoms2030|      549|      263|       7864|        2774|
# |  9|      Fraga125|      125|       88|       2358|        1449|
# +---+--------------+---------+---------+-----------+------------+
# only showing top 10 rows
